# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruva0101/NNDL-LAB-2022/blob/main/ANN_DEMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install keras==2.3.1

# %%
# !pip install tensorflow==2.0

# %%
pip install --upgrade pip

# %%
pip install --upgrade tensorflow

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
# Out:
# Using TensorFlow backend.

# %%
training_data = np.array([[0,0],[0,1],[1,0],[1,1]],"float32")

# %%
target_data = np.array([[0],[1],[1],[0]],"float32")

# %%
model = Sequential() 
model.add(Dense(16, input_dim=2, activation='relu')) 
model.add (Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error', 
              optimizer='adam',
              metrics=['binary_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 16)                48
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# ...
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(training_data, target_data, epochs=500, verbose=2)
# Out:
# Epoch 1/500
#  - 0s - loss: 0.2510 - binary_accuracy: 0.5000
# Epoch 2/500
#  - 0s - loss: 0.2506 - binary_accuracy: 0.5000
# Epoch 3/500
#  - 0s - loss: 0.2502 - binary_accuracy: 0.5000
# Epoch 4/500
#  - 0s - loss: 0.2499 - binary_accuracy: 0.5000
# Epoch 5/500
#  - 0s - loss: 0.2496 - binary_accuracy: 0.5000
# Epoch 6/500
#  - 0s - loss: 0.2492 - binary_accuracy: 0.5000
# Epoch 7/500
#  - 0s - loss: 0.2489 - binary_accuracy: 0.5000
# Epoch 8/500
#  - 0s - loss: 0.2486 - binary_accuracy: 0.5000
# Epoch 9/500
#  - 0s - loss: 0.2483 - binary_accuracy: 0.5000
# Epoch 10/500
#  - 0s - loss: 0.2479 - binary_accuracy: 0.5000
# Epoch 11/500
#  - 0s - loss: 0.2476 - binary_accuracy: 0.5000
# Epoch 12/500
#  - 0s - loss: 0.2473 - binary_accuracy: 0.5000
# Epoch 13/500
#  - 0s - loss: 0.2470 - binary_accuracy: 0.5000
# Epoch 14/500
#  - 0s - loss: 0.2468 - binary_accuracy: 0.5000
# Epoch 15/500
#  - 0s - loss: 0.2465 - binary_accuracy: 0.5000
# Epoch 16/500
# ...

# %%
model.predict(training_data).round()
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        [0.]], dtype=float32)
